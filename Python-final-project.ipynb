# %%
# pip install xlrd
# !pip install openpyxl

# %%
import os
assert os.path.isfile("DESeq2_kallisto_vsd.csv")

# %%
import pandas as pd
df_ctrlvsmut = pd.read_csv("DESeq2_kallisto_vsd.csv")
print(df)
df_ctrlvsmut
# Out:
#           Unnamed: 0      JP001      JP002      JP003      JP004      JP005  \
# 0      0610009B22Rik  10.425076  10.404924  10.571324  10.524966   9.789004
# 1      0610010F05Rik  11.681542  11.714794  11.472211  11.454169  10.604382
# 2      0610010K14Rik   9.891799   9.798628  10.095838   9.964367  10.093656
# 3      0610012G03Rik  11.820555  11.603109  12.073275  11.905223  11.602196
# 4      0610030E20Rik   9.875777   9.791588   9.871849   9.678772  10.139646
# ...              ...        ...        ...        ...        ...        ...
# 36139         Zyg11a   5.879159   5.879159   5.879159   5.879159   5.879159
# 36140         Zyg11b  11.998458  12.189784  11.957409  11.948443  11.331173
# 36141            Zyx  11.474158  11.016714  11.258902  11.350937  11.334157
# 36142          Zzef1  10.309166  10.235081  10.011170  10.363800  10.560365
# 36143           Zzz3  10.802367  10.668020  10.571166  10.738669  10.557733
#
#            JP006      JP007      JP008
# ...

# %%
#df_13 = pd.read_excel("pythonproject1.xlsx", engine='openpyxl', sheet_name='fold>1.3')
#df_13
# Out:
#      Unnamed: 0     baseMean  log2FoldChange     lfcSE       stat  \
# 0       Ldlrad3  2210.746135        1.797380  0.096093  18.704617
# 1         Igsf1   635.436952        3.114924  0.179527  17.350723
# 2       Tspan15  8619.394798        2.387348  0.138427  17.246199
# 3           Agt  9121.808017        3.938808  0.231468  17.016650
# 4        Sema6a  3733.431216        1.574166  0.096007  16.396433
# ...         ...          ...             ...       ...        ...
# 2034      Ifi47     7.263033        2.027882  0.878797   2.307565
# 2035     Trim61     2.706554        4.858686  2.107152   2.305807
# 2036    Ankrd55    16.546604        1.934251  0.841497   2.298583
# 2037     Ssmem1     7.928338        1.777143  0.773885   2.296391
# 2038       Lexm     7.838056        2.440200  1.062785   2.296044
#
#             pvalue          padj
# 0     4.539810e-78  9.223079e-74
# 1     1.947784e-67  1.978559e-63
# 2     1.195081e-66  8.093092e-63
# 3     6.180729e-65  3.139192e-61
# ...

# %%
df_ctrlvsmut
# Out:
#           Unnamed: 0      JP001      JP002      JP003      JP004      JP005  \
# 0      0610009B22Rik  10.425076  10.404924  10.571324  10.524966   9.789004
# 1      0610010F05Rik  11.681542  11.714794  11.472211  11.454169  10.604382
# 2      0610010K14Rik   9.891799   9.798628  10.095838   9.964367  10.093656
# 3      0610012G03Rik  11.820555  11.603109  12.073275  11.905223  11.602196
# 4      0610030E20Rik   9.875777   9.791588   9.871849   9.678772  10.139646
# ...              ...        ...        ...        ...        ...        ...
# 36139         Zyg11a   5.879159   5.879159   5.879159   5.879159   5.879159
# 36140         Zyg11b  11.998458  12.189784  11.957409  11.948443  11.331173
# 36141            Zyx  11.474158  11.016714  11.258902  11.350937  11.334157
# 36142          Zzef1  10.309166  10.235081  10.011170  10.363800  10.560365
# 36143           Zzz3  10.802367  10.668020  10.571166  10.738669  10.557733
#
#            JP006      JP007      JP008
# ...

# %%
from openpyxl import load_workbook
wb2 = load_workbook('pythonproject1.xlsx')
wb2.create_sheet('significantpadj')
wb2.save('pythonproject1.xlsx')

# %%
df['significant_padj']=df['padj']<0.05

# %%
df
# Out:
#       Unnamed: 0     baseMean  log2FoldChange     lfcSE       stat  \
# 0        Ldlrad3  2210.746135        1.797380  0.096093  18.704617
# 1          Igsf1   635.436952        3.114924  0.179527  17.350723
# 2        Tspan15  8619.394798        2.387348  0.138427  17.246199
# 3            Agt  9121.808017        3.938808  0.231468  17.016650
# 4       Trappc12  4122.262161       -1.379825  0.081887 -16.850276
# ...          ...          ...             ...       ...        ...
# 36139    Zscan4c     0.000000             NaN       NaN        NaN
# 36140    Zscan4d     0.000000             NaN       NaN        NaN
# 36141    Zscan4e     0.000000             NaN       NaN        NaN
# 36142    Zscan4f     0.000000             NaN       NaN        NaN
# 36143     Zyg11a     0.000000             NaN       NaN        NaN
#
#              pvalue          padj  significant_padj
# 0      4.539810e-78  9.223079e-74              True
# 1      1.947784e-67  1.978559e-63              True
# ...

# %%
from openpyxl import load_workbook
wb2 = load_workbook('pythonproject1.xlsx')
wb2.create_sheet('fold>1.3')
wb2.save('pythonproject1.xlsx')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# c:\Users\julap\OneDrive\Documents\IntroPythonExample\Python-final-project.ipynb Cell 7 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/julap/OneDrive/Documents/IntroPythonExample/Python-final-project.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> from openpyxl import load_workbook
# ----> <a href='vscode-notebook-cell:/c%3A/Users/julap/OneDrive/Documents/IntroPythonExample/Python-final-project.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> wb2 = load_workbook('pythonproject1.xlsx')
#       <a href='vscode-notebook-cell:/c%3A/Users/julap/OneDrive/Documents/IntroPythonExample/Python-final-project.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> wb2.create_sheet('fold>1.3')
# ...

# %%
df_upregulated = df_upregulated.get('fold>1.3')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\julap\OneDrive\Documents\IntroPythonExample\Python-final-project.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/julap/OneDrive/Documents/IntroPythonExample/Python-final-project.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> df_upregulated = df_upregulated.get('fold>1.3')
#
# NameError: name 'df_upregulated' is not defined

# %%
# load the project data

import pandas as pd
df_main = pd.read_excel("pythonproject1.xlsx", engine='openpyxl', sheet_name='Sheet1')
df_main
# df_upvsdown_13 = pd.read_excel("pythonproject1.xlsx", engine='openpyxl', sheet_name='fold>1.3')
# df_upvsdown_07 = pd.read_excel("pythonproject1.xlsx", engine='openpyxl', sheet_name='fold<0.7')
# Out:
#       Unnamed: 0     baseMean  log2FoldChange     lfcSE       stat  \
# 0        Ldlrad3  2210.746135        1.797380  0.096093  18.704617
# 1          Igsf1   635.436952        3.114924  0.179527  17.350723
# 2        Tspan15  8619.394798        2.387348  0.138427  17.246199
# 3            Agt  9121.808017        3.938808  0.231468  17.016650
# 4       Trappc12  4122.262161       -1.379825  0.081887 -16.850276
# ...          ...          ...             ...       ...        ...
# 36139    Zscan4c     0.000000             NaN       NaN        NaN
# 36140    Zscan4d     0.000000             NaN       NaN        NaN
# 36141    Zscan4e     0.000000             NaN       NaN        NaN
# 36142    Zscan4f     0.000000             NaN       NaN        NaN
# 36143     Zyg11a     0.000000             NaN       NaN        NaN
#
#              pvalue          padj
# 0      4.539810e-78  9.223079e-74
# 1      1.947784e-67  1.978559e-63
# 2      1.195081e-66  8.093092e-63
# ...

# %%
# load raw data from control and mutated groups

df_raw = pd.read_excel("estcountsgenes.xlsx", engine='openpyxl', sheet_name='Sheet1')
df_raw = df_raw.notna()
df_raw
# Out:
#        Unnamed: 0  JP001  JP002  JP003  JP004  JP005  JP006  JP007  JP008
# 0            True   True   True   True   True   True   True   True   True
# 1            True   True   True   True   True   True   True   True   True
# 2            True   True   True   True   True   True   True   True   True
# 3            True   True   True   True   True   True   True   True   True
# 4            True   True   True   True   True   True   True   True   True
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 36139        True   True   True   True   True   True   True   True   True
# 36140        True   True   True   True   True   True   True   True   True
# 36141        True   True   True   True   True   True   True   True   True
# 36142        True   True   True   True   True   True   True   True   True
# 36143        True   True   True   True   True   True   True   True   True
#
# [36144 rows x 9 columns]

# %%
# calculate the average

# %%
# !pip install bioinfokit
# Out:
# ...
#      ---------------------------------------- 87.0/87.0 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 9.1/9.1 MB 32.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      --------------------------------------- 14.7/14.7 MB 40.9 MB/s eta 0:00:00
# ...
#      ------------------------------------- 233.8/233.8 kB 14.0 MB/s eta 0:00:00
# ...
#   Created wheel for bioinfokit: filename=bioinfokit-2.1.0-py3-none-any.whl size=58669 sha256=96424af0bab2df51f26e412f7bd9ec7671e45381fdcc1b4f708d7393ae7eda87
#   Stored in directory: c:\users\julap\appdata\local\pip\cache\wheels\f8\6e\14\26f84dc04734d9b4614f1a74154aba345568d65c0c145c6543
# ...

# %%
df_raw
# Out:
#       Unnamed: 0     baseMean  log2FoldChange     lfcSE       stat  \
# 0        Ldlrad3  2210.746135        1.797380  0.096093  18.704617
# 1          Igsf1   635.436952        3.114924  0.179527  17.350723
# 2        Tspan15  8619.394798        2.387348  0.138427  17.246199
# 3            Agt  9121.808017        3.938808  0.231468  17.016650
# 4       Trappc12  4122.262161       -1.379825  0.081887 -16.850276
# ...          ...          ...             ...       ...        ...
# 36139    Zscan4c     0.000000             NaN       NaN        NaN
# 36140    Zscan4d     0.000000             NaN       NaN        NaN
# 36141    Zscan4e     0.000000             NaN       NaN        NaN
# 36142    Zscan4f     0.000000             NaN       NaN        NaN
# 36143     Zyg11a     0.000000             NaN       NaN        NaN
#
#              pvalue          padj
# 0      4.539810e-78  9.223079e-74
# 1      1.947784e-67  1.978559e-63
# 2      1.195081e-66  8.093092e-63
# ...

# %%
from bioinfokit import visuz
df_main_processed = df_main.dropna()
df_main_processed
visuz.GeneExpression.ma(df=df_main_processed, lfc='log2FoldChange', ct_count='baseMean', st_count='baseMean', pv='pvalue')

# %%
# df_upvsdown_13
# Out:
#      Unnamed: 0     baseMean  log2FoldChange     lfcSE       stat  \
# 0       Ldlrad3  2210.746135        1.797380  0.096093  18.704617
# 1         Igsf1   635.436952        3.114924  0.179527  17.350723
# 2       Tspan15  8619.394798        2.387348  0.138427  17.246199
# 3           Agt  9121.808017        3.938808  0.231468  17.016650
# 4        Sema6a  3733.431216        1.574166  0.096007  16.396433
# ...         ...          ...             ...       ...        ...
# 2034      Ifi47     7.263033        2.027882  0.878797   2.307565
# 2035     Trim61     2.706554        4.858686  2.107152   2.305807
# 2036    Ankrd55    16.546604        1.934251  0.841497   2.298583
# 2037     Ssmem1     7.928338        1.777143  0.773885   2.296391
# 2038       Lexm     7.838056        2.440200  1.062785   2.296044
#
#             pvalue          padj
# 0     4.539810e-78  9.223079e-74
# 1     1.947784e-67  1.978559e-63
# 2     1.195081e-66  8.093092e-63
# 3     6.180729e-65  3.139192e-61
# ...

# %%
# df_upvsdown_07
# Out:
#      Unnamed: 0     baseMean  log2FoldChange     lfcSE       stat  \
# 0      Trappc12  4122.262161       -1.379825  0.081887 -16.850276
# 1        Borcs5  2080.167238       -2.006245  0.121672 -16.489018
# 2        Ublcp1  2652.575929       -1.806956  0.118195 -15.287921
# 3          Med9  1498.655248       -1.593272  0.109812 -14.509084
# 4          Uros  1331.679995       -1.566054  0.108676 -14.410353
# ...         ...          ...             ...       ...        ...
# 5471    Dync1i2  2359.046337       -0.255390  0.111344  -2.293707
# 5472    Pomgnt1  7370.480803        0.206920  0.090212   2.293712
# 5473    Hcfc1r1  2525.963716       -0.418869  0.182639  -2.293421
# 5474       Guk1  5211.798646       -0.289346  0.126184  -2.293051
# 5475       Tsfm  1440.335766        0.223871  0.097653   2.292526
#
#             pvalue          padj
# 0     1.044254e-63  4.243011e-60
# 1     4.400406e-61  1.489978e-57
# 2     9.204205e-53  1.725936e-49
# 3     1.061290e-47  1.347572e-44
# ...

# %%
# df_upvsdown_13.columns = df_upvsdown_13.columns.str.replace('padj', 'padj_13')
# df_upvsdown_13
# Out:
#      Unnamed: 0     baseMean  log2FoldChange     lfcSE       stat  \
# 0       Ldlrad3  2210.746135        1.797380  0.096093  18.704617
# 1         Igsf1   635.436952        3.114924  0.179527  17.350723
# 2       Tspan15  8619.394798        2.387348  0.138427  17.246199
# 3           Agt  9121.808017        3.938808  0.231468  17.016650
# 4        Sema6a  3733.431216        1.574166  0.096007  16.396433
# ...         ...          ...             ...       ...        ...
# 2034      Ifi47     7.263033        2.027882  0.878797   2.307565
# 2035     Trim61     2.706554        4.858686  2.107152   2.305807
# 2036    Ankrd55    16.546604        1.934251  0.841497   2.298583
# 2037     Ssmem1     7.928338        1.777143  0.773885   2.296391
# 2038       Lexm     7.838056        2.440200  1.062785   2.296044
#
#             pvalue       padj_13
# 0     4.539810e-78  9.223079e-74
# 1     1.947784e-67  1.978559e-63
# 2     1.195081e-66  8.093092e-63
# 3     6.180729e-65  3.139192e-61
# ...

# %%
# df_upvsdown_07.columns = df_upvsdown_07.columns.str.replace('padj', 'padj_07')
# df_upvsdown_07
# Out:
#      Unnamed: 0     baseMean  log2FoldChange     lfcSE       stat  \
# 0      Trappc12  4122.262161       -1.379825  0.081887 -16.850276
# 1        Borcs5  2080.167238       -2.006245  0.121672 -16.489018
# 2        Ublcp1  2652.575929       -1.806956  0.118195 -15.287921
# 3          Med9  1498.655248       -1.593272  0.109812 -14.509084
# 4          Uros  1331.679995       -1.566054  0.108676 -14.410353
# ...         ...          ...             ...       ...        ...
# 5471    Dync1i2  2359.046337       -0.255390  0.111344  -2.293707
# 5472    Pomgnt1  7370.480803        0.206920  0.090212   2.293712
# 5473    Hcfc1r1  2525.963716       -0.418869  0.182639  -2.293421
# 5474       Guk1  5211.798646       -0.289346  0.126184  -2.293051
# 5475       Tsfm  1440.335766        0.223871  0.097653   2.292526
#
#             pvalue       padj_07
# 0     1.044254e-63  4.243011e-60
# 1     4.400406e-61  1.489978e-57
# 2     9.204205e-53  1.725936e-49
# 3     1.061290e-47  1.347572e-44
# ...

# %%
#df_combined = pd.concat([df_upvsdown_13, df_upvsdown_07['padj_07']], axis=1)
#df_combined
# Out:
#      Unnamed: 0     baseMean  log2FoldChange     lfcSE       stat  \
# 0       Ldlrad3  2210.746135        1.797380  0.096093  18.704617
# 1         Igsf1   635.436952        3.114924  0.179527  17.350723
# 2       Tspan15  8619.394798        2.387348  0.138427  17.246199
# 3           Agt  9121.808017        3.938808  0.231468  17.016650
# 4        Sema6a  3733.431216        1.574166  0.096007  16.396433
# ...         ...          ...             ...       ...        ...
# 5471        NaN          NaN             NaN       NaN        NaN
# 5472        NaN          NaN             NaN       NaN        NaN
# 5473        NaN          NaN             NaN       NaN        NaN
# 5474        NaN          NaN             NaN       NaN        NaN
# 5475        NaN          NaN             NaN       NaN        NaN
#
#             pvalue       padj_13       padj_07
# 0     4.539810e-78  9.223079e-74  4.243011e-60
# 1     1.947784e-67  1.978559e-63  1.489978e-57
# ...

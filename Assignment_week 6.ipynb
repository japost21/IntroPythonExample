# %%
import numpy as np
import pandas as pd

# %%
population=pd.read_csv('population_wb.csv')
population
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54208.0      55434.0      56234.0      56699.0
# ...

# %%
gdp=pd.read_csv('gdp.csv')
gdp
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  GDP (current US$)
# 1    Africa Eastern and Southern          AFE  GDP (current US$)
# 2                    Afghanistan          AFG  GDP (current US$)
# 3     Africa Western and Central          AFW  GDP (current US$)
# 4                         Angola          AGO  GDP (current US$)
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  GDP (current US$)
# 262                  Yemen, Rep.          YEM  GDP (current US$)
# 263                 South Africa          ZAF  GDP (current US$)
# 264                       Zambia          ZMB  GDP (current US$)
# 265                     Zimbabwe          ZWE  GDP (current US$)
#
#      Indicator Code          1960          1961          1962          1963  \
# 0    NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# ...

# %%
population = population.drop('Unnamed: 0', axis='columns')
population
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\julap\OneDrive\Documents\IntroPythonExample\Assignment_week 6.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/julap/OneDrive/Documents/IntroPythonExample/Assignment_week%206.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> population = population.drop('Unnamed: 0', axis='columns')
#       <a href='vscode-notebook-cell:/c%3A/Users/julap/OneDrive/Documents/IntroPythonExample/Assignment_week%206.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a> population
#
# File c:\Users\julap\miniconda3\envs\intropython\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
# ...

# %%
gdp = gdp.drop('Unnamed: 0', axis='columns')
gdp
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\julap\OneDrive\Documents\IntroPythonExample\Assignment_week 6.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/julap/OneDrive/Documents/IntroPythonExample/Assignment_week%206.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> gdp = gdp.drop('Unnamed: 0', axis='columns')
#       <a href='vscode-notebook-cell:/c%3A/Users/julap/OneDrive/Documents/IntroPythonExample/Assignment_week%206.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a> gdp
#
# File c:\Users\julap\miniconda3\envs\intropython\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
# ...

# %%
population_tidy = population.melt(
    id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'],
    var_name='year',      
    value_name='value'
)

# %%
population_tidy
# Out:
#                       Country Name Country Code     Indicator Name  \
# 0                            Aruba          ABW  Population, total
# 1      Africa Eastern and Southern          AFE  Population, total
# 2                      Afghanistan          AFG  Population, total
# 3       Africa Western and Central          AFW  Population, total
# 4                           Angola          AGO  Population, total
# ...                            ...          ...                ...
# 16487                       Kosovo          XKX  Population, total
# 16488                  Yemen, Rep.          YEM  Population, total
# 16489                 South Africa          ZAF  Population, total
# 16490                       Zambia          ZMB  Population, total
# 16491                     Zimbabwe          ZWE  Population, total
#
#       Indicator Code  year        value
# 0        SP.POP.TOTL  1960      54208.0
# 1        SP.POP.TOTL  1960  130836765.0
# ...

# %%
gdp_tidy = gdp.melt(
    id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'],
    var_name='year',      
    value_name='value'
)

# %%
gdp_tidy
# Out:
#                       Country Name Country Code     Indicator Name  \
# 0                            Aruba          ABW  GDP (current US$)
# 1      Africa Eastern and Southern          AFE  GDP (current US$)
# 2                      Afghanistan          AFG  GDP (current US$)
# 3       Africa Western and Central          AFW  GDP (current US$)
# 4                           Angola          AGO  GDP (current US$)
# ...                            ...          ...                ...
# 16487                       Kosovo          XKX  GDP (current US$)
# 16488                  Yemen, Rep.          YEM  GDP (current US$)
# 16489                 South Africa          ZAF  GDP (current US$)
# 16490                       Zambia          ZMB  GDP (current US$)
# 16491                     Zimbabwe          ZWE  GDP (current US$)
#
#        Indicator Code  year         value
# 0      NY.GDP.MKTP.CD  1960           NaN
# 1      NY.GDP.MKTP.CD  1960  2.129059e+10
# ...

# %%
display (population_tidy,gdp_tidy)
# Out:
#                       Country Name Country Code     Indicator Name  \
# 0                            Aruba          ABW  Population, total
# 1      Africa Eastern and Southern          AFE  Population, total
# 2                      Afghanistan          AFG  Population, total
# 3       Africa Western and Central          AFW  Population, total
# 4                           Angola          AGO  Population, total
# ...                            ...          ...                ...
# 16487                       Kosovo          XKX  Population, total
# 16488                  Yemen, Rep.          YEM  Population, total
# 16489                 South Africa          ZAF  Population, total
# 16490                       Zambia          ZMB  Population, total
# 16491                     Zimbabwe          ZWE  Population, total
#
#       Indicator Code  year        value
# 0        SP.POP.TOTL  1960      54208.0
# 1        SP.POP.TOTL  1960  130836765.0
# ...

# %%
df= (population_tidy,gdp_tidy)

# %%
display (df)
# Out:
# (                      Country Name Country Code     Indicator Name  \
#  0                            Aruba          ABW  Population, total
#  1      Africa Eastern and Southern          AFE  Population, total
#  2                      Afghanistan          AFG  Population, total
#  3       Africa Western and Central          AFW  Population, total
#  4                           Angola          AGO  Population, total
#  ...                            ...          ...                ...
#  16487                       Kosovo          XKX  Population, total
#  16488                  Yemen, Rep.          YEM  Population, total
#  16489                 South Africa          ZAF  Population, total
#  16490                       Zambia          ZMB  Population, total
#  16491                     Zimbabwe          ZWE  Population, total
#
#        Indicator Code  year        value
#  0        SP.POP.TOTL  1960      54208.0
#  1        SP.POP.TOTL  1960  130836765.0
# ...

# %%
result=pd.concat(df)
result
# Out:
#                       Country Name Country Code     Indicator Name  \
# 0                            Aruba          ABW  Population, total
# 1      Africa Eastern and Southern          AFE  Population, total
# 2                      Afghanistan          AFG  Population, total
# 3       Africa Western and Central          AFW  Population, total
# 4                           Angola          AGO  Population, total
# ...                            ...          ...                ...
# 16487                       Kosovo          XKX  GDP (current US$)
# 16488                  Yemen, Rep.          YEM  GDP (current US$)
# 16489                 South Africa          ZAF  GDP (current US$)
# 16490                       Zambia          ZMB  GDP (current US$)
# 16491                     Zimbabwe          ZWE  GDP (current US$)
#
#        Indicator Code  year         value
# 0         SP.POP.TOTL  1960  5.420800e+04
# 1         SP.POP.TOTL  1960  1.308368e+08
# ...

# %%
df = df.drop('Indicator Code', axis='columns')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\julap\OneDrive\Documents\IntroPythonExample\Assignment_week 6.ipynb Cell 14 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/julap/OneDrive/Documents/IntroPythonExample/Assignment_week%206.ipynb#X42sZmlsZQ%3D%3D?line=0'>1</a> df = df.drop('Indicator Code', axis='columns')
#
# AttributeError: 'tuple' object has no attribute 'drop'

# %%
df.pivot(index='Country Name', 'Country Code',	'Indicator Name', 'year', 'value', columns='Country Code', value='value')
# Out:
#   Input In [46]
#     df.pivot(index='Country Name', 'Country Code',	'Indicator Name', 'year', 'value', columns='Country Code', value='value')
#                                                   	                                                                        ^
# SyntaxError: positional argument follows keyword argument

# %%
df.reset_index
